# %% [markdown]
# <a href="https://colab.research.google.com/github/kishorekishu4/07-01-2025/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df.loc[5, 'Age'] = np.nan
df.loc[9, 'Salary'] = np.nan
df.head(10)
# Out:
#     Age    Salary  purchased  Gender       city
# 0  56.0   92955.0          1  Female     Mumbai
# 1  69.0   94925.0          0  Female    Chennai
# 2  46.0   97969.0          0    Male     Mumbai
# 3  32.0   35311.0          0  Female      Delhi
# 4  60.0  113104.0          0    Male  Bangalore
# 5   NaN   83707.0          0  Female     Mumbai
# 6  38.0  115305.0          0    Male     Mumbai
# 7  56.0   58693.0          0  Female    Chennai
# 8  36.0  101932.0          0    Male     Mumbai
# 9  40.0       NaN          1    Male     Mumbai

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Salary'].fillna(df['Salary'].median(), inplace=True)
df.head(10)
# Out:
#          Age    Salary  purchased  Gender       city
# 0  56.000000   92955.0          1  Female     Mumbai
# 1  69.000000   94925.0          0  Female    Chennai
# 2  46.000000   97969.0          0    Male     Mumbai
# 3  32.000000   35311.0          0  Female      Delhi
# 4  60.000000  113104.0          0    Male  Bangalore
# 5  42.105263   83707.0          0  Female     Mumbai
# 6  38.000000  115305.0          0    Male     Mumbai
# 7  56.000000   58693.0          0  Female    Chennai
# 8  36.000000  101932.0          0    Male     Mumbai
# 9  40.000000   94925.0          1    Male     Mumbai

# %%
df_dropped = df.dropna()
df_dropped.head(10)
# Out:
#          Age    Salary  purchased  Gender       city
# 0  56.000000   92955.0          1  Female     Mumbai
# 1  69.000000   94925.0          0  Female    Chennai
# 2  46.000000   97969.0          0    Male     Mumbai
# 3  32.000000   35311.0          0  Female      Delhi
# 4  60.000000  113104.0          0    Male  Bangalore
# 5  42.105263   83707.0          0  Female     Mumbai
# 6  38.000000  115305.0          0    Male     Mumbai
# 7  56.000000   58693.0          0  Female    Chennai
# 8  36.000000  101932.0          0    Male     Mumbai
# 9  40.000000   94925.0          1    Male     Mumbai

# %%
from sklearn.impute import KNNImputer
knn_imputer = KNNImputer(n_neighbors=3)
df[['Age', 'Salary']] = knn_imputer.fit_transform(df[['Age', 'Salary']])
print(df[['Age', 'Salary']])
# Out:
#           Age    Salary
# 0   56.000000   92955.0
# 1   69.000000   94925.0
# 2   46.000000   97969.0
# 3   32.000000   35311.0
# 4   60.000000  113104.0
# 5   42.105263   83707.0
# 6   38.000000  115305.0
# 7   56.000000   58693.0
# 8   36.000000  101932.0
# 9   40.000000   94925.0
# 10  28.000000  114478.0
# 11  28.000000   48431.0
# 12  41.000000   32747.0
# 13  53.000000   89150.0
# 14  57.000000   95725.0
# 15  41.000000  114654.0
# 16  20.000000   65773.0
# 17  39.000000   97435.0
# 18  19.000000   86886.0
# 19  41.000000   96803.0

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
np.random.seed(42)
def createdata():
  data ={
      'Age': np.random.randint(18,70,size=20),
      'Salary': np.random.randint(30000,120000,size=20),
      'purchased': np.random.choice([0,1],size=20),
      'Gender': np.random.choice(['Male','Female'],size=20),
      'city': np.random.choice(['Delhi','Mumbai','Bangalore','Chennai'],size=20)
  }
  df = pd.DataFrame(data)
  return df
df = createdata()
print(df)
# Out:
#     Age  Salary  purchased  Gender       city
# 0    56   92955          1  Female     Mumbai
# 1    69   94925          0  Female    Chennai
# 2    46   97969          0    Male     Mumbai
# 3    32   35311          0  Female      Delhi
# 4    60  113104          0    Male  Bangalore
# 5    25   83707          0  Female     Mumbai
# 6    38  115305          0    Male     Mumbai
# 7    56   58693          0  Female    Chennai
# 8    36  101932          0    Male     Mumbai
# 9    40   55658          1    Male     Mumbai
# 10   28  114478          1  Female     Mumbai
# 11   28   48431          0    Male    Chennai
# 12   41   32747          1  Female     Mumbai
# 13   53   89150          1  Female  Bangalore
# 14   57   95725          1  Female    Chennai
# 15   41  114654          1  Female  Bangalore
# 16   20   65773          0  Female    Chennai
# 17   39   97435          1  Female     Mumbai
# 18   19   86886          0  Female  Bangalore
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Gender'] = label_encoder.fit_transform(df['Gender'])
df.head()
# Out:
#     Age    Salary  purchased  Gender       city
# 0  56.0   92955.0          1       0     Mumbai
# 1  69.0   94925.0          0       0    Chennai
# 2  46.0   97969.0          0       1     Mumbai
# 3  32.0   35311.0          0       0      Delhi
# 4  60.0  113104.0          0       1  Bangalore

# %%
df = pd.get_dummies(df, columns=['city'], drop_first=True)
df.head()
# Out:
#     Age    Salary  purchased  Gender  city_Chennai  city_Delhi  city_Mumbai
# 0  56.0   92955.0          1       0         False       False         True
# 1  69.0   94925.0          0       0          True       False        False
# 2  46.0   97969.0          0       1         False       False         True
# 3  32.0   35311.0          0       0         False        True        False
# 4  60.0  113104.0          0       1         False       False        False
